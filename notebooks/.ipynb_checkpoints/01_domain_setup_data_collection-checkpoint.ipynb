# %% [markdown]
# ### Phase 1: Data Collection (Nifty 100: From 01-01-2020 till date)

# %%
# ==========================================
# Phase 1: Data Collection (NIFTY 100)
# ==========================================

from nselib import capital_market
import pandas as pd
from datetime import date, datetime
import time
import requests
import feedparser
from urllib.parse import quote_plus
import shutil
from pathlib import Path
from transformers import pipeline

# %%
# -----------------------------
# Step 0: Project Setup
# -----------------------------
PROJECT_ROOT = Path().resolve().parent
DATA_DIR = PROJECT_ROOT / "data"

RAW_DIR = DATA_DIR / "raw"
NEWS_DIR = DATA_DIR / "news_raw"

# Clean full data directory
if DATA_DIR.exists():
    shutil.rmtree(DATA_DIR)

RAW_DIR.mkdir(parents=True, exist_ok=True)
NEWS_DIR.mkdir(parents=True, exist_ok=True)

print("Clean data directories ready.")
# Out:
# Clean data directories ready.

# %%
# -----------------------------
# Step 1: Load FinBERT
# -----------------------------
sentiment_model = pipeline(
    "sentiment-analysis",
    model="ProsusAI/finbert",
    framework="pt",
)

print("FinBERT loaded.")
# Out:
# Device set to use cpu
# FinBERT loaded.

# %%
# -----------------------------
# Step 2: Fetch NIFTY 100 tickers
# -----------------------------
url = "https://archives.nseindia.com/content/indices/ind_nifty100list.csv"
df_list = pd.read_csv(url)

tickers = df_list["Symbol"].tolist()

print(f"Total tickers fetched: {len(tickers)}")
# Out:
# Total tickers fetched: 100

# %%
# -----------------------------
# Step 3: News Fetch Function
# -----------------------------
def clean_text(text):
    return text.replace("\n", " ").strip()


def fetch_news_sentiment(symbol, max_items=100):

    query = f"""
    {symbol} stock OR {symbol} earnings OR {symbol} results
    site:reuters.com OR
    site:bloomberg.com OR
    site:cnbc.com OR
    site:economictimes.indiatimes.com OR
    site:business-standard.com OR
    site:livemint.com OR
    site:moneycontrol.com OR
    site:ndtvprofit.com OR
    site:financialexpress.com OR
    site:thehindubusinessline.com
    """

    query_encoded = quote_plus(query)

    url = f"https://news.google.com/rss/search?q={query_encoded}&hl=en-IN&gl=IN&ceid=IN:en"

    feed = feedparser.parse(url)

    records = []

    for entry in feed.entries[:max_items]:

        if not hasattr(entry, "published_parsed"):
            continue

        text = clean_text(entry.title)
        date_pub = datetime(*entry.published_parsed[:6])

        try:
            sent = sentiment_model(text)[0]
            score = sent["score"] if sent["label"] == "positive" else -sent["score"]
        except:
            continue

        records.append(
            {
                "ticker": symbol,
                "date": date_pub.date(),
                "headline": text,
                "sentiment_score": score,
            }
        )

    df = pd.DataFrame(records)
    df = df.drop_duplicates(subset=["headline"])

    return df

# %%
# -----------------------------
# Step 4: Fetch Price + News
# -----------------------------
def fetch_all_data(symbols, start, end):

    failed = []

    for symbol in symbols:

        try:
            print(f"\n📦 Fetching {symbol} ...")

            df = capital_market.price_volume_and_deliverable_position_data(
                symbol=symbol,
                from_date=start.strftime("%d-%m-%Y"),
                to_date=end.strftime("%d-%m-%Y"),
            )

            if df.empty:
                print(f"⚠️ No price data for {symbol}")
                failed.append(symbol)
                continue

            df.columns = df.columns.str.lower().str.strip()

            # Keep only EQ series
            if "series" in df.columns:
                df = df[df["series"].str.upper() == "EQ"].copy()

                if df.empty:
                    print(f"⚠️ {symbol} has no EQ data")
                    failed.append(symbol)
                    continue

            # Save price
            df.to_csv(RAW_DIR / f"{symbol}.csv", index=False)
            print(f"✅ Price saved")

            # Fetch news
            news_df = fetch_news_sentiment(symbol)

            if not news_df.empty:
                news_df.to_csv(NEWS_DIR / f"{symbol}_news.csv", index=False)
                print(f"📰 News saved ({len(news_df)})")

        except Exception as e:
            print(f"❌ Failed: {symbol} | {e}")
            failed.append(symbol)

        time.sleep(1)

    print("\n✅ Data Fetch Completed.")
    print(f"✅ Success: {len(symbols) - len(failed)} | ❌ Failed: {len(failed)}")

    if failed:
        pd.DataFrame(failed, columns=["Symbol"]).to_csv(
            DATA_DIR / "failed_tickers.csv", index=False
        )
        print("⚠️ Failed tickers saved.")

# %%
# -----------------------------
# Step 5: Execute
# -----------------------------
START_DATE = date(2020, 1, 1)
END_DATE = date.today()

fetch_all_data(tickers, START_DATE, END_DATE)

print("\n Phase 1 completed.")
print("Total RAW files:", len(list(RAW_DIR.glob("*.csv"))))
# Out:
# 📦 Fetching ABB ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching ADANIENSOL ...
# ✅ Price saved
# 📰 News saved (6)
#
# 📦 Fetching ADANIENT ...
# ✅ Price saved
# 📰 News saved (98)
#
# 📦 Fetching ADANIGREEN ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching ADANIPORTS ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching ADANIPOWER ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching AMBUJACEM ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching APOLLOHOSP ...
# ✅ Price saved
# 📰 News saved (23)
#
# 📦 Fetching ASIANPAINT ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching DMART ...
# ✅ Price saved
# 📰 News saved (97)
#
# 📦 Fetching AXISBANK ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching BAJAJ-AUTO ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching BAJFINANCE ...
# ✅ Price saved
# 📰 News saved (14)
#
# 📦 Fetching BAJAJFINSV ...
# ✅ Price saved
# 📰 News saved (9)
#
# 📦 Fetching BAJAJHLDNG ...
# ✅ Price saved
# 📰 News saved (5)
#
# 📦 Fetching BANKBARODA ...
# ✅ Price saved
# 📰 News saved (73)
#
# 📦 Fetching BEL ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching BPCL ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching BHARTIARTL ...
# ✅ Price saved
# 📰 News saved (20)
#
# 📦 Fetching BOSCHLTD ...
# ✅ Price saved
# 📰 News saved (74)
#
# 📦 Fetching BRITANNIA ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching CGPOWER ...
# ✅ Price saved
# 📰 News saved (98)
#
# 📦 Fetching CANBK ...
# ✅ Price saved
# 📰 News saved (21)
#
# 📦 Fetching CHOLAFIN ...
# ✅ Price saved
# 📰 News saved (23)
#
# 📦 Fetching CIPLA ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching COALINDIA ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching CUMMINSIND ...
# ✅ Price saved
# 📰 News saved (4)
#
# 📦 Fetching DLF ...
# ✅ Price saved
# 📰 News saved (94)
#
# 📦 Fetching DIVISLAB ...
# ✅ Price saved
# 📰 News saved (19)
#
# 📦 Fetching DRREDDY ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching EICHERMOT ...
# ✅ Price saved
# 📰 News saved (9)
#
# 📦 Fetching ETERNAL ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching GAIL ...
# ✅ Price saved
# 📰 News saved (98)
#
# 📦 Fetching GODREJCP ...
# ✅ Price saved
# 📰 News saved (10)
#
# 📦 Fetching GRASIM ...
# ✅ Price saved
# 📰 News saved (95)
#
# 📦 Fetching HCLTECH ...
# ✅ Price saved
# 📰 News saved (97)
#
# 📦 Fetching HDFCAMC ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching HDFCBANK ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching HDFCLIFE ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching HINDALCO ...
# ✅ Price saved
# 📰 News saved (96)
#
# 📦 Fetching HAL ...
# ✅ Price saved
# 📰 News saved (97)
#
# 📦 Fetching HINDUNILVR ...
# ✅ Price saved
# 📰 News saved (52)
#
# 📦 Fetching HINDZINC ...
# ✅ Price saved
# 📰 News saved (21)
#
# 📦 Fetching HYUNDAI ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching ICICIBANK ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching ITC ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching INDHOTEL ...
# ✅ Price saved
# 📰 News saved (10)
#
# 📦 Fetching IOC ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching IRFC ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching INFY ...
# ✅ Price saved
# 📰 News saved (98)
#
# 📦 Fetching INDIGO ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching JSWSTEEL ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching JINDALSTEL ...
# ✅ Price saved
# 📰 News saved (4)
#
# 📦 Fetching JIOFIN ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching KOTAKBANK ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching LTM ...
# ✅ Price saved
# 📰 News saved (97)
#
# 📦 Fetching LT ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching LODHA ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching M&M ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching MARUTI ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching MAXHEALTH ...
# ✅ Price saved
# 📰 News saved (60)
#
# 📦 Fetching MAZDOCK ...
# ✅ Price saved
# 📰 News saved (37)
#
# 📦 Fetching MUTHOOTFIN ...
# ✅ Price saved
# 📰 News saved (10)
#
# 📦 Fetching NTPC ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching NESTLEIND ...
# ✅ Price saved
# 📰 News saved (6)
#
# 📦 Fetching ONGC ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching PIDILITIND ...
# ✅ Price saved
# 📰 News saved (3)
#
# 📦 Fetching PFC ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching POWERGRID ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching PNB ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching RECLTD ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching RELIANCE ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching SBILIFE ...
# ✅ Price saved
# 📰 News saved (98)
#
# 📦 Fetching MOTHERSON ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching SHREECEM ...
# ✅ Price saved
# 📰 News saved (6)
#
# 📦 Fetching SHRIRAMFIN ...
# ✅ Price saved
# 📰 News saved (9)
#
# 📦 Fetching ENRIN ...
# ✅ Price saved
# 📰 News saved (98)
#
# 📦 Fetching SIEMENS ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching SOLARINDS ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching SBIN ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching SUNPHARMA ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching TVSMOTOR ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching TATACAP ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching TCS ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching TATACONSUM ...
# ✅ Price saved
# 📰 News saved (5)
#
# 📦 Fetching TMCV ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching TMPV ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching TATAPOWER ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching TATASTEEL ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching TECHM ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching TITAN ...
# ✅ Price saved
# 📰 News saved (97)
#
# 📦 Fetching TORNTPHARM ...
# ✅ Price saved
# 📰 News saved (4)
#
# 📦 Fetching TRENT ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching ULTRACEMCO ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching UNIONBANK ...
# ✅ Price saved
# 📰 News saved (100)
#
# 📦 Fetching UNITDSPR ...
# ✅ Price saved
# 📰 News saved (5)
#
# 📦 Fetching VBL ...
# ✅ Price saved
# 📰 News saved (96)
#
# 📦 Fetching VEDL ...
# ✅ Price saved
# 📰 News saved (98)
#
# 📦 Fetching WIPRO ...
# ✅ Price saved
# 📰 News saved (99)
#
# 📦 Fetching ZYDUSLIFE ...
# ✅ Price saved
# 📰 News saved (54)
#
# ✅ Data Fetch Completed.
# ✅ Success: 100 | ❌ Failed: 0
#
#  Phase 1 completed.
# Total RAW files: 100
